# %% [markdown]
# # Pandas
# ### (Panda, Panda, Panda)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Indexing list

# %%
list1 = ['Shashank','Saket','Shaurya','Divy','Raghav']
index = [1,2,3,4,5]
custom_index = ['ich','ni','sun','say','go']

custom_indexed = pd.Series(list1 , custom_index)
indexed = pd.Series(list1 , index)

# %%
print(indexed)

## Custom index can be set 
custom_indexed
# Out:
# 1    Shashank
# 2       Saket
# 3     Shaurya
# 4        Divy
# 5      Raghav
# dtype: object
# ich    Shashank
# ni        Saket
# sun     Shaurya
# say        Divy
# go       Raghav
# dtype: object

# %%
 ## Can index the values by default or map them with another list
    
arr1 = np.array([1,3,5,2,6] ,dtype = 'float32') 
ser1 = pd.Series(arr1)
print(ser1 , '\n\n')

dict1 = {'f_name' : 'Shashank' , 'l_name' : 'Chaudhary' , 'age' : 18 , 'l_achievement' : 12}

## doesn't necessarily need to have the name to create a series using dictionary
 ### AS IN CASE OF APPENDING (mentioned below (somewhere))
ser2 = pd.Series(dict1 , name='converting dictionaries')
print(ser2 , '\n\nname of the sereis: ' , ser2.name)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    2.0
# 4    6.0
# dtype: float32
#
#
# f_name            Shashank
# l_name           Chaudhary
# age                     18
# l_achievement           12
# Name: converting dictionaries, dtype: object
#
# name of the sereis:  converting dictionaries

# %% [markdown]
# ## Dataframes

# %% [markdown]
# ### Creating dataframes

# %%
arr = np.random.randint(10,50,size=(2,3))
df1 = pd.DataFrame(arr , ['A','B'],['C','D','E'])
df1
# Out:
#     C   D   E
# A  19  43  15
# B  31  16  32

# %%
dict3 = {'one' : pd.Series([1,2,3], index = ['a','b','c']) , 'two' : pd.Series([1,2,3,4], index= ['a','b','c','d'])}

pd.DataFrame(dict3)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
dict([('a',[1,2,3]),('b',[4,5,6])])
# Out:
# {'a': [1, 2, 3], 'b': [4, 5, 6]}

# %%
## Dataframes using dictionary
## Dataframe.from_dict is not necessarily needed unless orient needs to be different from
## default
pd.DataFrame.from_dict(dict([('a',[1,2,3]),('b',[4,5,6])]))
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df3 = pd.DataFrame.from_dict(dict([('a',[1,2,3]),('b',[4,5,6])]) , orient= 'index' , columns=['one','two','three'])
df3
# Out:
#    one  two  three
# a    1    2      3
# b    4    5      6

# %% [markdown]
# ## Editing and Retrieving Data

# %%
print(df3 , '\n')
print(df3[['one','three']] , '\n') 
print(df3.loc['a','one'],'\n')
print(df3.iloc[1],'\n')
print(df3.loc[['a','b'],['one','three']])
df3['Total'] = df3['one']+df3['two']+df3['three'] 
df3
# Out:
#    one  two  three
# a    1    2      3
# b    4    5      6
#
#    one  three
# a    1      3
# b    4      6
#
# 1
#
# one      4
# two      5
# three    6
# Name: b, dtype: int64
#
#    one  three
# a    1      3
# b    4      6
#    one  two  three  Total
# a    1    2      3      6
# b    4    5      6     15

# %%
new_row = {'one' : 8 , 'two' : 23, 'three' : 'new'}

## Can append the dictionary only if ignore_index = True
print(df3.append(new_row , ignore_index=True))

## Doesn't change the df3 unless done (df3 = df3.append(new_row , ignore_index = True))
df3
# Out:
#    one  two three  Total
# 0    1    2     3    6.0
# 1    4    5     6   15.0
# 2    8   23   new    NaN
#    one  two  three  Total
# a    1    2      3      6
# b    4    5      6     15

# %%
n_row = pd.Series(new_row , name = 'S')

## Can only append the series if sereis has a name or ignore_index = True
df3.append(n_row)
# Out:
#    one  two three  Total
# a    1    2     3    6.0
# b    4    5     6   15.0
# S    8   23   new    NaN

# %% [markdown]
# # Pandas COREY SCHAFER tutorial

# %% [markdown]
# ### Reading data from pandas

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0       European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1      Pound sterling  ...                         NaN                    NaN
# 2                 NaN  ...  Neither easy nor difficult  Appropriate in length
# 3        Albanian lek  ...                         NaN                    NaN
# 4                 NaN  ...                        Easy              Too short
# ...               ...  ...                         ...                    ...
# 64456             NaN  ...                         NaN                    NaN
# 64457             NaN  ...                         NaN                    NaN
# 64458             NaN  ...                         NaN                    NaN
# 64459             NaN  ...                         NaN                    NaN
# 64460             NaN  ...                         NaN                    NaN
#
#       Trans                                     UndergradMajor  \
# 0        No  Computer science, computer engineering, or sof...
# 1       NaN  Computer science, computer engineering, or sof...
# 2       NaN                                                NaN
# 3        No  Computer science, computer engineering, or sof...
# 4        No  Computer science, computer engineering, or sof...
# ...     ...                                                ...
# 64456   NaN  Computer science, computer engineering, or sof...
# 64457   NaN                                                NaN
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year        50.0        36
# 1      Somewhat more welcome now than last year         NaN         7
# 2      Somewhat more welcome now than last year         NaN         4
# 3      Somewhat less welcome now than last year        40.0         7
# 4       Just as welcome now as I felt last year         NaN        15
# ...                                         ...         ...       ...
# 64456                                       NaN         NaN        10
# 64457                                       NaN         NaN       NaN
# 64458                                       NaN         NaN       NaN
# 64459                                       NaN         NaN       NaN
# 64460                                       NaN         NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
def isInt(value):
    try:
        int(value)
        return True
    except ValueError:
        return False

# %%
age_list = [int(age) for age in df['Age1stCode'] if isInt(age)]

# %%
df.shape ## Dimensionality of the DataFrame
# Out:
# (64461, 61)

# %%
df.info() ## Concise Summary of a Dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
#  12  DatabaseWorkedWith            49537 non-null  object
#  13  DevType                       49370 non-null  object
#  14  EdLevel                       57431 non-null  object
#  15  Employment                    63854 non-null  object
#  16  Ethnicity                     45948 non-null  object
#  17  Gender                        50557 non-null  object
#  18  JobFactors                    49349 non-null  object
#  19  JobSat                        45194 non-null  object
#  20  JobSeek                       51727 non-null  object
#  21  LanguageDesireNextYear        54113 non-null  object
#  22  LanguageWorkedWith            57378 non-null  object
#  23  MiscTechDesireNextYear        42379 non-null  object
#  24  MiscTechWorkedWith            40314 non-null  object
#  25  NEWCollabToolsDesireNextYear  47287 non-null  object
#  26  NEWCollabToolsWorkedWith      52883 non-null  object
#  27  NEWDevOps                     42686 non-null  object
#  28  NEWDevOpsImpt                 41732 non-null  object
#  29  NEWEdImpt                     48465 non-null  object
#  30  NEWJobHunt                    42286 non-null  object
#  31  NEWJobHuntResearch            41022 non-null  object
#  32  NEWLearn                      56156 non-null  object
#  33  NEWOffTopic                   50804 non-null  object
#  34  NEWOnboardGood                42623 non-null  object
#  35  NEWOtherComms                 57205 non-null  object
#  36  NEWOvertime                   43231 non-null  object
#  37  NEWPurchaseResearch           37321 non-null  object
#  38  NEWPurpleLink                 54803 non-null  object
#  39  NEWSOSites                    58275 non-null  object
#  40  NEWStuck                      54983 non-null  object
#  41  OpSys                         56228 non-null  object
#  42  OrgSize                       44334 non-null  object
#  43  PlatformDesireNextYear        50605 non-null  object
#  44  PlatformWorkedWith            53843 non-null  object
#  45  PurchaseWhat                  39364 non-null  object
#  46  Sexuality                     43992 non-null  object
#  47  SOAccount                     56805 non-null  object
#  48  SOComm                        56476 non-null  object
#  49  SOPartFreq                    46792 non-null  object
#  50  SOVisitFreq                   56970 non-null  object
#  51  SurveyEase                    51802 non-null  object
#  52  SurveyLength                  51701 non-null  object
#  53  Trans                         49345 non-null  object
#  54  UndergradMajor                50995 non-null  object
#  55  WebframeDesireNextYear        40024 non-null  object
#  56  WebframeWorkedWith            42279 non-null  object
#  57  WelcomeChange                 52683 non-null  object
#  58  WorkWeekHrs                   41151 non-null  float64
#  59  YearsCode                     57684 non-null  object
#  60  YearsCodePro                  46349 non-null  object
# dtypes: float64(4), int64(1), object(56)
# memory usage: 30.0+ MB

# %%
pd.set_option('display.max_columns',61) ## Changing my settings to show all the columns

# %%
df ## Showing all the columns
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
#         Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0       NaN         13  Monthly        NaN            NaN             Germany
# 1       NaN         19      NaN        NaN            NaN      United Kingdom
# 2       NaN         15      NaN        NaN            NaN  Russian Federation
# 3      25.0         18      NaN        NaN            NaN             Albania
# 4      31.0         16      NaN        NaN            NaN       United States
# ...     ...        ...      ...        ...            ...                 ...
# 64456   NaN         16      NaN        NaN            NaN       United States
# 64457   NaN        NaN      NaN        NaN            NaN             Morocco
# 64458   NaN        NaN      NaN        NaN            NaN            Viet Nam
# 64459   NaN        NaN      NaN        NaN            NaN              Poland
# 64460   NaN        NaN      NaN        NaN            NaN               Spain
#
#          CurrencyDesc CurrencySymbol  \
# 0       European Euro            EUR
# 1      Pound sterling            GBP
# 2                 NaN            NaN
# 3        Albanian lek            ALL
# 4                 NaN            NaN
# ...               ...            ...
# 64456             NaN            NaN
# 64457             NaN            NaN
# 64458             NaN            NaN
# 64459             NaN            NaN
# 64460             NaN            NaN
#
#                                   DatabaseDesireNextYear  \
# 0                                   Microsoft SQL Server
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                       MySQL;PostgreSQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459    DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL
# 64460                       MariaDB;Microsoft SQL Server
#
#                                       DatabaseWorkedWith  \
# 0              Elasticsearch;Microsoft SQL Server;Oracle
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                          MySQL;PostgreSQL;Redis;SQLite
# ...                                                  ...
# 64456                                                NaN
# 64457  Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 64458                                                NaN
# 64459                                             Oracle
# 64460          MariaDB;Microsoft SQL Server;MySQL;Oracle
#
#                                                  DevType  \
# 0      Developer, desktop or enterprise applications;...
# 1                Developer, full-stack;Developer, mobile
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64456                                Senior executive/VP
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                              NaN
# 64458                        Primary/elementary school
# 64459                                              NaN
# 64460       Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Employed full-time
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Employed full-time
# ...                                                  ...
# 64456                                 Employed full-time
# 64457                                 Employed full-time
# 64458                                                NaN
# 64459                                 Employed full-time
# 64460                                 Employed full-time
#
#                           Ethnicity Gender  \
# 0      White or of European descent    Man
# 1                               NaN    NaN
# 2                               NaN    NaN
# 3      White or of European descent    Man
# 4      White or of European descent    Man
# ...                             ...    ...
# 64456                           NaN    NaN
# 64457                           NaN    NaN
# 64458                           NaN    NaN
# 64459                           NaN    NaN
# 64460                           NaN    NaN
#
#                                               JobFactors  \
# 0      Languages, frameworks, and other technologies ...
# 1                                                    NaN
# 2                                                    NaN
# 3      Flex time or a flexible schedule;Office enviro...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                       JobSat  \
# 0         Slightly satisfied
# 1          Very dissatisfied
# 2                        NaN
# 3      Slightly dissatisfied
# 4                        NaN
# ...                      ...
# 64456                    NaN
# 64457                    NaN
# 64458                    NaN
# 64459                    NaN
# 64460                    NaN
#
#                                                  JobSeek  \
# 0           I am not interested in new job opportunities
# 1           I am not interested in new job opportunities
# 2                                                    NaN
# 3      I’m not actively looking, but I am open to new...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                   LanguageDesireNextYear  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                           Python;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                        Java;Ruby;Scala
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                           HTML/CSS;Java;JavaScript
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                                       LanguageWorkedWith  \
# 0                                 C#;HTML/CSS;JavaScript
# 1                                       JavaScript;Swift
# 2                               Objective-C;Python;Swift
# 3                                                    NaN
# 4                                      HTML/CSS;Ruby;SQL
# ...                                                  ...
# 64456                                                NaN
# 64457  Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                NaN
# 64459                                           HTML/CSS
# 64460                    C#;HTML/CSS;Java;JavaScript;SQL
#
#                  MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                     .NET Core;Xamarin     .NET;.NET Core
# 1      React Native;TensorFlow;Unity 3D       React Native
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                          Ansible;Chef            Ansible
# ...                                 ...                ...
# 64456                               NaN                NaN
# 64457                               NaN                NaN
# 64458                               NaN                NaN
# 64459                           Node.js                NaN
# 64460                 .NET Core;Xamarin     .NET;.NET Core
#
#                  NEWCollabToolsDesireNextYear  \
# 0      Microsoft Teams;Microsoft Azure;Trello
# 1                                Github;Slack
# 2                                         NaN
# 3                                         NaN
# 4       Github;Google Suite (Docs, Meet, etc)
# ...                                       ...
# 64456                                     NaN
# 64457                                     NaN
# 64458                                     NaN
# 64459                           Github;Gitlab
# 64460                  Github;Microsoft Teams
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# 0           Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN        No
# 4      Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                  ...       ...
# 64456                                                NaN       NaN
# 64457                                                NaN       NaN
# 64458                                                NaN       NaN
# 64459              Confluence;Jira;Slack;Microsoft Teams       NaN
# 64460                                             Github       NaN
#
#             NEWDevOpsImpt                           NEWEdImpt  \
# 0      Somewhat important                    Fairly important
# 1                     NaN                    Fairly important
# 2                     NaN                                 NaN
# 3                     NaN  Not at all important/not necessary
# 4                     NaN                      Very important
# ...                   ...                                 ...
# 64456                 NaN                      Very important
# 64457                 NaN                                 NaN
# 64458                 NaN                                 NaN
# 64459                 NaN                                 NaN
# 64460                 NaN                Critically important
#
#                                               NEWJobHunt NEWJobHuntResearch  \
# 0                                                    NaN                NaN
# 1                                                    NaN                NaN
# 2                                                    NaN                NaN
# 3      Curious about other opportunities;Wanting to w...                NaN
# 4                                                    NaN                NaN
# ...                                                  ...                ...
# 64456                                                NaN                NaN
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                                NaN                NaN
# 64460                                                NaN                NaN
#
#             NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0        Once a year    Not sure            NaN            No
# 1        Once a year    Not sure            NaN            No
# 2      Once a decade         NaN            NaN            No
# 3        Once a year    Not sure            Yes           Yes
# 4        Once a year          No            NaN           Yes
# ...              ...         ...            ...           ...
# 64456  Once a decade         NaN            NaN           NaN
# 64457            NaN         NaN            NaN           NaN
# 64458            NaN         NaN            NaN           NaN
# 64459    Once a year         NaN            NaN           NaN
# 64460    Once a year         NaN            NaN           NaN
#
#                                              NEWOvertime  \
# 0                       Often: 1-2 days per week or more
# 1                                                    NaN
# 2                                                    NaN
# 3      Occasionally: 1-2 days per quarter but less th...
# 4                                                    NaN
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                                                NaN
#
#                                      NEWPurchaseResearch      NEWPurpleLink  \
# 0      Start a free trial;Ask developers I know/work ...             Amused
# 1                                                    NaN             Amused
# 2                                                    NaN                NaN
# 3                                                    NaN                NaN
# 4      Start a free trial;Ask developers I know/work ...  Hello, old friend
# ...                                                  ...                ...
# 64456                                 Start a free trial             Amused
# 64457                                                NaN                NaN
# 64458                                                NaN                NaN
# 64459                                 Start a free trial  Hello, old friend
# 64460  Start a free trial;Ask developers I know/work ...        Indifferent
#
#                                               NEWSOSites  \
# 0       Stack Overflow (public Q&A for anyone who codes)
# 1      Stack Overflow (public Q&A for anyone who code...
# 2       Stack Overflow (public Q&A for anyone who codes)
# 3      Stack Overflow (public Q&A for anyone who code...
# 4      Stack Overflow (public Q&A for anyone who code...
# ...                                                  ...
# 64456   Stack Overflow (public Q&A for anyone who codes)
# 64457                                                NaN
# 64458                                                NaN
# 64459   Stack Overflow (public Q&A for anyone who codes)
# 64460                                                NaN
#
#                                                 NEWStuck        OpSys  \
# 0      Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1      Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                    NaN  Linux-based
# 3                                                    NaN  Linux-based
# 4      Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                  ...          ...
# 64456                          Call a coworker or friend      Windows
# 64457                                                NaN          NaN
# 64458                                                NaN          NaN
# 64459     Call a coworker or friend;Visit Stack Overflow      Windows
# 64460  Meditate;Visit Stack Overflow;Go for a walk or...      Windows
#
#                         OrgSize  \
# 0              2 to 9 employees
# 1      1,000 to 4,999 employees
# 2                           NaN
# 3            20 to 99 employees
# 4                           NaN
# ...                         ...
# 64456                       NaN
# 64457                       NaN
# 64458                       NaN
# 64459                       NaN
# 64460                       NaN
#
#                                   PlatformDesireNextYear  \
# 0         Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                             iOS;Kubernetes;Linux;MacOS
# 2                                                    NaN
# 3                                                    NaN
# 4      Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                  ...
# 64456                                                NaN
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460                 Arduino;Linux;Raspberry Pi;Windows
#
#                                PlatformWorkedWith  \
# 0                                         Windows
# 1                                             iOS
# 2                                             NaN
# 3                                             NaN
# 4                  AWS;Docker;Linux;MacOS;Windows
# ...                                           ...
# 64456                                         NaN
# 64457                                         NaN
# 64458                                         NaN
# 64459                               Linux;Windows
# 64460  Android;Arduino;Linux;Raspberry Pi;Windows
#
#                            PurchaseWhat                Sexuality SOAccount  \
# 0                                   NaN  Straight / Heterosexual        No
# 1         I have little or no influence                      NaN       Yes
# 2                                   NaN                      NaN       Yes
# 3      I have a great deal of influence  Straight / Heterosexual       Yes
# 4                                   NaN  Straight / Heterosexual       Yes
# ...                                 ...                      ...       ...
# 64456                               NaN                      NaN       NaN
# 64457                               NaN                      NaN       NaN
# 64458                               NaN                      NaN       NaN
# 64459                               NaN                      NaN       NaN
# 64460                               NaN                      NaN       NaN
#
#                 SOComm                           SOPartFreq  \
# 0       No, not at all                                  NaN
# 1      Yes, definitely  Less than once per month or monthly
# 2        Yes, somewhat      A few times per month or weekly
# 3      Yes, definitely      A few times per month or weekly
# 4        Yes, somewhat  Less than once per month or monthly
# ...                ...                                  ...
# 64456              NaN                                  NaN
# 64457              NaN                                  NaN
# 64458              NaN                                  NaN
# 64459              NaN                                  NaN
# 64460              NaN                                  NaN
#
#                            SOVisitFreq                  SurveyEase  \
# 0               Multiple times per day  Neither easy nor difficult
# 1               Multiple times per day                         NaN
# 2                Daily or almost daily  Neither easy nor difficult
# 3               Multiple times per day                         NaN
# 4      A few times per month or weekly                        Easy
# ...                                ...                         ...
# 64456                              NaN                         NaN
# 64457                              NaN                         NaN
# 64458                              NaN                         NaN
# 64459                              NaN                         NaN
# 64460                              NaN                         NaN
#
#                 SurveyLength Trans  \
# 0      Appropriate in length    No
# 1                        NaN   NaN
# 2      Appropriate in length   NaN
# 3                        NaN    No
# 4                  Too short    No
# ...                      ...   ...
# 64456                    NaN   NaN
# 64457                    NaN   NaN
# 64458                    NaN   NaN
# 64459                    NaN   NaN
# 64460                    NaN   NaN
#
#                                           UndergradMajor  \
# 0      Computer science, computer engineering, or sof...
# 1      Computer science, computer engineering, or sof...
# 2                                                    NaN
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# ...                                                  ...
# 64456  Computer science, computer engineering, or sof...
# 64457                                                NaN
# 64458                                                NaN
# 64459                                                NaN
# 64460  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# 0                     ASP.NET Core                    ASP.NET;ASP.NET Core
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4             Django;Ruby on Rails                           Ruby on Rails
# ...                            ...                                     ...
# 64456                          NaN                                     NaN
# 64457                          NaN                                     NaN
# 64458                          NaN                                     NaN
# 64459  Angular;Angular.js;React.js                                     NaN
# 64460          ASP.NET Core;jQuery  Angular;Angular.js;ASP.NET Core;jQuery
#
#                                   WelcomeChange  WorkWeekHrs YearsCode  \
# 0       Just as welcome now as I felt last year         50.0        36
# 1      Somewhat more welcome now than last year          NaN         7
# 2      Somewhat more welcome now than last year          NaN         4
# 3      Somewhat less welcome now than last year         40.0         7
# 4       Just as welcome now as I felt last year          NaN        15
# ...                                         ...          ...       ...
# 64456                                       NaN          NaN        10
# 64457                                       NaN          NaN       NaN
# 64458                                       NaN          NaN       NaN
# 64459                                       NaN          NaN       NaN
# 64460                                       NaN          NaN       NaN
#
#            YearsCodePro
# 0                    27
# 1                     4
# 2                   NaN
# 3                     4
# 4                     8
# ...                 ...
# 64456  Less than 1 year
# 64457               NaN
# 64458               NaN
# 64459               NaN
# 64460               NaN
#
# [64461 rows x 61 columns]

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
pd.set_option('display.max_rows' , 61)
print(schema_df.head(6))  ## First 6 data rows
schema_df.tail(6) ## Last 6 data rows
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?
# 3         Age  What is your age (in years)? If you prefer not...
# 4  Age1stCode  At what age did you write your first line of c...
# 5    CompFreq   Is that compensation weekly, monthly, or yearly?
#                     Column                                       QuestionText
# 55  WebframeDesireNextYear  Which web frameworks have you done extensive d...
# 56      WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57           WelcomeChange  Compared to last year, how welcome do you feel...
# 58             WorkWeekHrs  On average, how many hours per week do you wor...
# 59               YearsCode  Including any education, how many years have y...
# 60            YearsCodePro  NOT including education, how many years have y...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0   European Euro            EUR   Microsoft SQL Server
# 1  Pound sterling            GBP                    NaN
# 2             NaN            NaN                    NaN
# 3    Albanian lek            ALL                    NaN
# 4             NaN            NaN       MySQL;PostgreSQL
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
#
#      LanguageDesireNextYear        LanguageWorkedWith  \
# 0    C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 1              Python;Swift          JavaScript;Swift
# 2  Objective-C;Python;Swift  Objective-C;Python;Swift
# 3                       NaN                       NaN
# 4           Java;Ruby;Scala         HTML/CSS;Ruby;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
#
#         NEWDevOpsImpt                           NEWEdImpt  \
# 0  Somewhat important                    Fairly important
# 1                 NaN                    Fairly important
# 2                 NaN                                 NaN
# 3                 NaN  Not at all important/not necessary
# 4                 NaN                      Very important
#
#                                           NEWJobHunt NEWJobHuntResearch  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  Curious about other opportunities;Wanting to w...                NaN
# 4                                                NaN                NaN
#
#         NEWLearn NEWOffTopic NEWOnboardGood NEWOtherComms  \
# 0    Once a year    Not sure            NaN            No
# 1    Once a year    Not sure            NaN            No
# 2  Once a decade         NaN            NaN            No
# 3    Once a year    Not sure            Yes           Yes
# 4    Once a year          No            NaN           Yes
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                     OrgSize  \
# 0          2 to 9 employees
# 1  1,000 to 4,999 employees
# 2                       NaN
# 3        20 to 99 employees
# 4                       NaN
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                PlatformWorkedWith                      PurchaseWhat  \
# 0                         Windows                               NaN
# 1                             iOS     I have little or no influence
# 2                             NaN                               NaN
# 3                             NaN  I have a great deal of influence
# 4  AWS;Docker;Linux;MacOS;Windows                               NaN
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
# 2                                                NaN                    NaN
# 3  Computer science, computer engineering, or sof...                    NaN
# 4  Computer science, computer engineering, or sof...   Django;Ruby on Rails
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8

# %%
### shashank.k.chaudhary@gmail.com

# %%
## Again creating a dataframe using dictionary
people = {
    'f_name' : ['Shashank','Saket','Raghav','Divy'],
    'l_name' : ['Chaudhary' ,'', 'Saboo','Badgurjar'],
    'email' : ['shashank.k.chaudhary@gmail.com','saket@gmail.com','saboo.raghav@gmail.com','divy.bd@gmail.com'],
    'loc' : ['Darbhanga','Patna','Gurgaon','Jaipur']
}

# %%
dict_df = pd.DataFrame(people)
## list of f_name is sereis, list of l_name is series , list of email is sereis and list of loc in series
dict_df
# Out:
#      f_name     l_name                           email        loc
# 0  Shashank  Chaudhary  shashank.k.chaudhary@gmail.com  Darbhanga
# 1     Saket                            saket@gmail.com      Patna
# 2    Raghav      Saboo          saboo.raghav@gmail.com    Gurgaon
# 3      Divy  Badgurjar               divy.bd@gmail.com     Jaipur

# %%
print(dict_df.email, '\n')

## GIVES THE EXACTLY SAME THING
dict_df['email']
# Out:
# 0    shashank.k.chaudhary@gmail.com
# 1                   saket@gmail.com
# 2            saboo.raghav@gmail.com
# 3                 divy.bd@gmail.com
# Name: email, dtype: object
# 0    shashank.k.chaudhary@gmail.com
# 1                   saket@gmail.com
# 2            saboo.raghav@gmail.com
# 3                 divy.bd@gmail.com
# Name: email, dtype: object

# %%
print(type(dict_df['email']))

## Noticed that even the empty cell is being counted -> pd is taking that as a string 
## used '' to fill the ap and it is a String 
### Doesn't show NaN
dict_df.count()
# Out:
# <class 'pandas.core.series.Series'>
# f_name    4
# l_name    4
# email     4
# loc       4
# dtype: int64

# %%
## Getting comlumns in a DataFrame
print(df.columns)

## row information at index 0
df.iloc[0]
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# DatabaseWorkedWith                      Elasticsearch;Microsoft SQL Server;Oracle
# DevType                         Developer, desktop or enterprise applications;...
# EdLevel                           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                      Independent contractor, freelancer, or self-em...
# Ethnicity                                            White or of European descent
# Gender                                                                        Man
# JobFactors                      Languages, frameworks, and other technologies ...
# JobSat                                                         Slightly satisfied
# JobSeek                              I am not interested in new job opportunities
# LanguageDesireNextYear                                     C#;HTML/CSS;JavaScript
# LanguageWorkedWith                                         C#;HTML/CSS;JavaScript
# MiscTechDesireNextYear                                          .NET Core;Xamarin
# MiscTechWorkedWith                                                 .NET;.NET Core
# NEWCollabToolsDesireNextYear               Microsoft Teams;Microsoft Azure;Trello
# NEWCollabToolsWorkedWith             Confluence;Jira;Slack;Microsoft Azure;Trello
# NEWDevOps                                                                      No
# NEWDevOpsImpt                                                  Somewhat important
# NEWEdImpt                                                        Fairly important
# NEWJobHunt                                                                    NaN
# NEWJobHuntResearch                                                            NaN
# NEWLearn                                                              Once a year
# NEWOffTopic                                                              Not sure
# NEWOnboardGood                                                                NaN
# NEWOtherComms                                                                  No
# NEWOvertime                                      Often: 1-2 days per week or more
# NEWPurchaseResearch             Start a free trial;Ask developers I know/work ...
# NEWPurpleLink                                                              Amused
# NEWSOSites                       Stack Overflow (public Q&A for anyone who codes)
# NEWStuck                        Visit Stack Overflow;Go for a walk or other ph...
# OpSys                                                                     Windows
# OrgSize                                                          2 to 9 employees
# PlatformDesireNextYear             Android;iOS;Kubernetes;Microsoft Azure;Windows
# PlatformWorkedWith                                                        Windows
# PurchaseWhat                                                                  NaN
# Sexuality                                                 Straight / Heterosexual
# SOAccount                                                                      No
# SOComm                                                             No, not at all
# SOPartFreq                                                                    NaN
# SOVisitFreq                                                Multiple times per day
# SurveyEase                                             Neither easy nor difficult
# SurveyLength                                                Appropriate in length
# Trans                                                                          No
# UndergradMajor                  Computer science, computer engineering, or sof...
# WebframeDesireNextYear                                               ASP.NET Core
# WebframeWorkedWith                                           ASP.NET;ASP.NET Core
# WelcomeChange                             Just as welcome now as I felt last year
# WorkWeekHrs                                                                  50.0
# YearsCode                                                                      36
# YearsCodePro                                                                   27
# Name: 0, dtype: object

# %% [markdown]
# ### Retreiving data from DataFrame

# %%
## iloc is basically integer location
## DataFrame.iloc[list of rows, list of columns]
df.iloc[[1,6],[1,5]]
# Out:
#                        MainBranch CompFreq
# 1  I am a developer by profession      NaN
# 6  I am a developer by profession  Monthly

# %%
dict_df
# Out:
#      f_name     l_name                           email        loc
# 0  Shashank  Chaudhary  shashank.k.chaudhary@gmail.com  Darbhanga
# 1     Saket                            saket@gmail.com      Patna
# 2    Raghav      Saboo          saboo.raghav@gmail.com    Gurgaon
# 3      Divy  Badgurjar               divy.bd@gmail.com     Jaipur

# %%
## loc is the label based location
## Because index has integer as the label we can access them using the integer

## We get the resultant DataFrame in the same Order as in the list
dict_df.loc[[2,0],['f_name','email']]
# Out:
#      f_name                           email
# 2    Raghav          saboo.raghav@gmail.com
# 0  Shashank  shashank.k.chaudhary@gmail.com

# %%
## to use the slicing we need not give the sqaure brackets as in case of list

## unlike slicing in python, last index is inclusive
## we get the index from 0-4 including 4 and Age-Country including 'Country'
df.loc[0:4, 'Age':'Country']
# Out:
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States

# %% [markdown]
# ### Setting index

# %%
## Setting one of the columns as index
## Doesn't modify the dataFrame itself unless done explicitly

dict_df.set_index('email')
# Out:
#                                   f_name     l_name        loc
# email
# shashank.k.chaudhary@gmail.com  Shashank  Chaudhary  Darbhanga
# saket@gmail.com                    Saket                 Patna
# saboo.raghav@gmail.com            Raghav      Saboo    Gurgaon
# divy.bd@gmail.com                   Divy  Badgurjar     Jaipur

# %%
dict_df
# Out:
#      f_name     l_name                           email        loc
# 0  Shashank  Chaudhary  shashank.k.chaudhary@gmail.com  Darbhanga
# 1     Saket                            saket@gmail.com      Patna
# 2    Raghav      Saboo          saboo.raghav@gmail.com    Gurgaon
# 3      Divy  Badgurjar               divy.bd@gmail.com     Jaipur

# %%
## to change the DataFraem itself we use inplace = True

dict_df.set_index('email' , inplace = True)

# %%
dict_df
# Out:
#                                   f_name     l_name        loc
# email
# shashank.k.chaudhary@gmail.com  Shashank  Chaudhary  Darbhanga
# saket@gmail.com                    Saket                 Patna
# saboo.raghav@gmail.com            Raghav      Saboo    Gurgaon
# divy.bd@gmail.com                   Divy  Badgurjar     Jaipur

# %%
dict_df.index
# Out:
# Index(['shashank.k.chaudhary@gmail.com', 'saket@gmail.com',
#        'saboo.raghav@gmail.com', 'divy.bd@gmail.com'],
#       dtype='object', name='email')

# %%
dict_df.loc['shashank.k.chaudhary@gmail.com','l_name']

## Can't use dict_df.loc[0] anymore but can use dict_df.iloc[0]
# Out:
# 'Chaudhary'

# %%
### Resting index to the default

dict_df.reset_index(inplace=True)
dict_df
# Out:
#                             email    f_name     l_name        loc
# 0  shashank.k.chaudhary@gmail.com  Shashank  Chaudhary  Darbhanga
# 1                 saket@gmail.com     Saket                 Patna
# 2          saboo.raghav@gmail.com    Raghav      Saboo    Gurgaon
# 3               divy.bd@gmail.com      Divy  Badgurjar     Jaipur

# %%
### In case if we can set one of the columns as the index when reading the csv
df_schema = pd.read_csv('data/survey_results_schema.csv' , index_col='Column')

# %%
## As we can see the column is acting as the index
df_schema.loc['Respondent']
# Out:
# QuestionText    Randomized respondent ID number (not in order ...
# Name: Respondent, dtype: object

# %%
## Data sorted in albhabetical order
df_schema.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# EdLevel                       Which of the following best describes the high...
# Employment                    Which of the following best describes your cur...
# Ethnicity                     Which of the following describe you, if any? P...
# Gender                        Which of the following describe you, if any? P...
# Hobbyist                                                Do you code as a hobby?
# JobFactors                    Imagine that you are deciding between two job ...
# JobSat                        How satisfied are you with your current job? (...
# JobSeek                       Which of the following best describes your cur...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# MainBranch                    Which of the following options best describes ...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWStuck                      What do you do when you get stuck on a problem...
# OpSys                         What is the primary operating system in which ...
# OrgSize                       Approximately how many people are employed by ...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PurchaseWhat                  What level of influence do you, personally, ha...
# Respondent                    Randomized respondent ID number (not in order ...
# SOAccount                                 Do you have a Stack Overflow account?
# SOComm                        Do you consider yourself a member of the Stack...
# SOPartFreq                    How frequently would you say you participate i...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# Sexuality                     Which of the following describe you, if any? P...
# SurveyEase                    How easy or difficult was this survey to compl...
# SurveyLength                  How do you feel about the length of the survey...
# Trans                                                      Are you transgender?
# UndergradMajor                            What was your primary field of study?
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# YearsCode                     Including any education, how many years have y...
# YearsCodePro                  NOT including education, how many years have y...

# %%
## Can also do this in the reverse order 
df_schema.sort_index(ascending = False, inplace = True)

## Whenever we want to make changes and save it directly to our dataFrame we use 
## "Inplace = True"
df_schema
# Out:
#                                                                    QuestionText
# Column
# YearsCodePro                  NOT including education, how many years have y...
# YearsCode                     Including any education, how many years have y...
# WorkWeekHrs                   On average, how many hours per week do you wor...
# WelcomeChange                 Compared to last year, how welcome do you feel...
# WebframeWorkedWith            Which web frameworks have you done extensive d...
# WebframeDesireNextYear        Which web frameworks have you done extensive d...
# UndergradMajor                            What was your primary field of study?
# Trans                                                      Are you transgender?
# SurveyLength                  How do you feel about the length of the survey...
# SurveyEase                    How easy or difficult was this survey to compl...
# Sexuality                     Which of the following describe you, if any? P...
# SOVisitFreq                   How frequently would you say you visit Stack O...
# SOPartFreq                    How frequently would you say you participate i...
# SOComm                        Do you consider yourself a member of the Stack...
# SOAccount                                 Do you have a Stack Overflow account?
# Respondent                    Randomized respondent ID number (not in order ...
# PurchaseWhat                  What level of influence do you, personally, ha...
# PlatformWorkedWith            Which platforms have you done extensive develo...
# PlatformDesireNextYear        Which platforms have you done extensive develo...
# OrgSize                       Approximately how many people are employed by ...
# OpSys                         What is the primary operating system in which ...
# NEWStuck                      What do you do when you get stuck on a problem...
# NEWSOSites                    Which of the following Stack Overflow sites ha...
# NEWPurpleLink                 You search for a coding solution online and th...
# NEWPurchaseResearch           When buying a new tool or software, how do you...
# NEWOvertime                   How often do you work overtime or beyond the f...
# NEWOtherComms                 Are you a member of any other online developer...
# NEWOnboardGood                Do you think your company has a good onboardin...
# NEWOffTopic                   Do you think Stack Overflow should relax restr...
# NEWLearn                      How frequently do you learn a new language or ...
# NEWJobHuntResearch            When job searching, how do you learn more abou...
# NEWJobHunt                    In general, what drives you to look for a new ...
# NEWEdImpt                     How important is a formal education, such as a...
# NEWDevOpsImpt                 How important is the practice of DevOps to sca...
# NEWDevOps                     Does your company have a dedicated DevOps person?
# NEWCollabToolsWorkedWith      Which collaboration tools have you done extens...
# NEWCollabToolsDesireNextYear  Which collaboration tools have you done extens...
# MiscTechWorkedWith            Which other frameworks, libraries, and tools h...
# MiscTechDesireNextYear        Which other frameworks, libraries, and tools h...
# MainBranch                    Which of the following options best describes ...
# LanguageWorkedWith            Which programming, scripting, and markup langu...
# LanguageDesireNextYear        Which programming, scripting, and markup langu...
# JobSeek                       Which of the following best describes your cur...
# JobSat                        How satisfied are you with your current job? (...
# JobFactors                    Imagine that you are deciding between two job ...
# Hobbyist                                                Do you code as a hobby?
# Gender                        Which of the following describe you, if any? P...
# Ethnicity                     Which of the following describe you, if any? P...
# Employment                    Which of the following best describes your cur...
# EdLevel                       Which of the following best describes the high...
# DevType                       Which of the following describe you? Please se...
# DatabaseWorkedWith            Which database environments have you done exte...
# DatabaseDesireNextYear        Which database environments have you done exte...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# Country                                                      Where do you live?
# ConvertedComp                 Salary converted to annual USD salaries using ...
# CompTotal                     What is your current total compensation (salar...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# Age1stCode                    At what age did you write your first line of c...
# Age                           What is your age (in years)? If you prefer not...

# %% [markdown]
# ## Filtering the data

# %%
## Did this by mistake but we can see that it gives all the values of that column the same value (only helpful when we need to concatenate datasets and add another column to differentiate the data)
dict_df['l_name'] = ''

# %%
dict_df
# Out:
#                             email    f_name l_name        loc
# 0  shashank.k.chaudhary@gmail.com  Shashank         Darbhanga
# 1                 saket@gmail.com     Saket             Patna
# 2          saboo.raghav@gmail.com    Raghav           Gurgaon
# 3               divy.bd@gmail.com      Divy            Jaipur

# %%
## Gives the boolean of the series of the column
dict_df['f_name'] == 'Saket'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: f_name, dtype: bool

# %%
filt = (dict_df['f_name'] == 'Shashank')

### Both gives the same output
print(dict_df[filt])
print(dict_df.loc[filt])

dict_df.loc[filt, 'email']
# Out:
#                             email    f_name l_name        loc
# 0  shashank.k.chaudhary@gmail.com  Shashank         Darbhanga
#                             email    f_name l_name        loc
# 0  shashank.k.chaudhary@gmail.com  Shashank         Darbhanga
# 0    shashank.k.chaudhary@gmail.com
# Name: email, dtype: object

# %%
new_dict = {'fname' : ['Shashank' , 'Divy' , 'Raghav' , 'Abhinav' , 'Gowrinath'] , 'lname' : ['Chaudhary' , 'Badgurjar' , 'Saboo', 'Kumar' , ''] , 'email' : ['shashank.k.chaudhary@gmail.com' , 'divy@gmail.com' , 'saboo@email.com' , 'abhinav@gmail.com' , 'gowri@gmail.com'] , 'Branch' : ['IT' , 'EEE' , 'EEE' , 'IT' , 'EEE' ]}

df_new = pd.DataFrame(new_dict)

# %%
## & and | used instead of 'and'  and 'or' as in case of pure python

filt_new = (df_new['Branch'] == 'IT') & (df_new['fname'] == 'Shashank')
df_new.loc[filt_new , 'email']
# Out:
# 0    shashank.k.chaudhary@gmail.com
# Name: email, dtype: object

# %%
filt_new = (df_new['Branch'] == 'IT') | (df_new['fname'] == 'Divy')

## negation of the filter using '~'
df_new.loc[~filt_new , 'email']
# Out:
# 2    saboo@email.com
# 4    gowri@gmail.com
# Name: email, dtype: object

# %%
## high_salary is finding rows with salary>70000 , country : India and Language contains Python {na:False}(means ignore NaN values)
high_salary = (df['ConvertedComp'] > 70000) & (df['Country'] == 'India') & (df['LanguageWorkedWith'].str.contains('Python' , na =False))

## Getting the high_salary values and few other columns and droping the NaN value containing rows
## Before droping NaN value rows we had 13178 rows and after that we had 12756
## "& (df['Country'] == 'India'" added later

print(df.loc[high_salary , ['Country' , 'LanguageWorkedWith' , 'ConvertedComp']].shape)
df.loc[high_salary , ['Country' , 'LanguageWorkedWith' , 'ConvertedComp']].dropna()
# Out:
# (63, 3)
#       Country                                 LanguageWorkedWith  \
# 277     India  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 3318    India                           Go;Java;Python;Scala;SQL
# 3586    India  Bash/Shell/PowerShell;Go;Java;JavaScript;Kotli...
# 5886    India  Bash/Shell/PowerShell;Dart;HTML/CSS;Java;Kotli...
# 6084    India                      C#;HTML/CSS;JavaScript;Python
# ...       ...                                                ...
# 54218   India  Bash/Shell/PowerShell;C;C#;C++;Dart;HTML/CSS;J...
# 54254   India      HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 58170   India                                         Python;SQL
# 60727   India  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
# 64053   India  Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...
#
#        ConvertedComp
# 277         150792.0
# 3318       1000000.0
# 3586         75396.0
# 5886        134028.0
# 6084        435600.0
# ...              ...
# 54218       167544.0
# 54254       301572.0
# 58170       753936.0
# 60727        83770.0
# 64053        75396.0
#
# [63 rows x 3 columns]

# %%
df_new.columns
# Out:
# Index(['fname', 'lname', 'email', 'Branch'], dtype='object')

# %% [markdown]
# ### Renaming column names

# %%
## one way to do is using the list comprehension but only if we need to make similar changes to all the column names
## e.g. rpelacing space with underscore, or lower case or upper case or something similar

df_new.columns = [x.upper() for x in df_new.columns]
df_new
# Out:
#        FNAME      LNAME                           EMAIL BRANCH
# 0   Shashank  Chaudhary  shashank.k.chaudhary@gmail.com     IT
# 1       Divy  Badgurjar                  divy@gmail.com    EEE
# 2     Raghav      Saboo                 saboo@email.com    EEE
# 3    Abhinav      Kumar               abhinav@gmail.com     IT
# 4  Gowrinath                            gowri@gmail.com    EEE

# %%
## I liked the lower case names better so I am going to revert it back to as it was
df_new.columns = [x.lower() for x in df_new.columns]
df_new
# Out:
#        fname      lname                           email branch
# 0   Shashank  Chaudhary  shashank.k.chaudhary@gmail.com     IT
# 1       Divy  Badgurjar                  divy@gmail.com    EEE
# 2     Raghav      Saboo                 saboo@email.com    EEE
# 3    Abhinav      Kumar               abhinav@gmail.com     IT
# 4  Gowrinath                            gowri@gmail.com    EEE

# %%
## If we want to chnage the names of the columns to something new

df_new.rename(columns = {'fname' : 'f_name' , 'lname' : 'l_name'} , inplace = True)
## pass columns as dictionary in format old_name : new_name in DataFrame.rename

# %%
df_new
# Out:
#       f_name     l_name                           email branch
# 0   Shashank  Chaudhary  shashank.k.chaudhary@gmail.com     IT
# 1       Divy  Badgurjar                  divy@gmail.com    EEE
# 2     Raghav      Saboo                 saboo@email.com    EEE
# 3    Abhinav      Kumar               abhinav@gmail.com     IT
# 4  Gowrinath                            gowri@gmail.com    EEE

# %%
df_new['school'] = pd.Series(['SITE' , 'SELECT' , 'SELECT' , 'SITE', 'SELECT'])
df_new
# Out:
#       f_name     l_name                           email branch  school
# 0   Shashank  Chaudhary  shashank.k.chaudhary@gmail.com     IT    SITE
# 1       Divy  Badgurjar                  divy@gmail.com    EEE  SELECT
# 2     Raghav      Saboo                 saboo@email.com    EEE  SELECT
# 3    Abhinav      Kumar               abhinav@gmail.com     IT    SITE
# 4  Gowrinath                            gowri@gmail.com    EEE  SELECT

# %%
df_new.pop('branch')
# Out:
# 0     IT
# 1    EEE
# 2    EEE
# 3     IT
# 4    EEE
# Name: branch, dtype: object

# %%
df_new
# Out:
#       f_name     l_name                           email  school
# 0   Shashank  Chaudhary  shashank.k.chaudhary@gmail.com    SITE
# 1       Divy  Badgurjar                  divy@gmail.com  SELECT
# 2     Raghav      Saboo                 saboo@email.com  SELECT
# 3    Abhinav      Kumar               abhinav@gmail.com    SITE
# 4  Gowrinath                            gowri@gmail.com  SELECT

# %%
df_new[['f_name','school']][[x=='SITE' for x in df_new['school']]]
# Out:
#      f_name school
# 0  Shashank   SITE
# 3   Abhinav   SITE

# %%
## updating row values more than one at a time
df_new.loc[4 , ['l_name' , 'f_name']] = ['Nath' , 'Gowri']
df_new
# Out:
#      f_name     l_name                           email  school
# 0  Shashank  Chaudhary  shashank.k.chaudhary@gmail.com    SITE
# 1      Divy  Badgurjar                  divy@gmail.com  SELECT
# 2    Raghav      Saboo                 saboo@email.com  SELECT
# 3   Abhinav      Kumar               abhinav@gmail.com    SITE
# 4     Gowri       Nath                 gowri@gmail.com  SELECT

# %%
## ## ### #### # NOTE!!!

## updating values using filters
## create a filter let it be "filt"

## df[filt]['l_name'] = 'Smith' (this can't be done as this gives a copy not the dataFram)

## instead we do this df.loc[filt , 'l_name'] = 'Smith'

# %%
df_new['f_name'] = df_new['f_name'].str.upper()
df_new
# Out:
#      f_name     l_name                           email  school
# 0  SHASHANK  Chaudhary  shashank.k.chaudhary@gmail.com    SITE
# 1      DIVY  Badgurjar                  divy@gmail.com  SELECT
# 2    RAGHAV      Saboo                 saboo@email.com  SELECT
# 3   ABHINAV      Kumar               abhinav@gmail.com    SITE
# 4     GOWRI       Nath                 gowri@gmail.com  SELECT

# %%
### apply , map , applymap , replace
## dataFrame['column_name'].apply(func)

## What it does is func(column_name_values) for each row

df_new['l_name'].apply(len)
# Out:
# 0    9
# 1    9
# 2    5
# 3    5
# 4    4
# Name: l_name, dtype: int64

# %%
## apply to a DataFrame
print(df_new.apply(len))
df_new.apply(len , axis = 'columns')
# Out:
# f_name    5
# l_name    5
# email     5
# school    5
# dtype: int64
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
## apply the func to every elelment inside the DataFrame
df_new.applymap(len)
# Out:
#    f_name  l_name  email  school
# 0       8       9     30       4
# 1       4       9     14       6
# 2       6       5     15       6
# 3       7       5     17       4
# 4       5       4     15       6

# %%
## map method works on the series only
## this makes all the other values that hasn't beed touched as NaN

df_new['l_name'].map({'Chaudhary' : 'chy' , 'Badgurjar' : 'Bd' , 'Saboo' : 'Sb'})
# Out:
# 0    chy
# 1     Bd
# 2     Sb
# 3    NaN
# 4    NaN
# Name: l_name, dtype: object

# %%
## this only replaces the value that we want to and preserve the rest of the values
df_new['l_name'].replace({'Chaudhary': 'Chy' , 'Badgurjar' : 'Bd'})
# Out:
# 0      Chy
# 1       Bd
# 2    Saboo
# 3    Kumar
# 4     Nath
# Name: l_name, dtype: object

# %%
df_new['school'].replace({'SITE' : 'IT'})
# Out:
# 0        IT
# 1    SELECT
# 2    SELECT
# 3        IT
# 4    SELECT
# Name: school, dtype: object

# %%
df_new.rename(columns = {'school' : 'branch'} , inplace = True)

# %%
df_new
# Out:
#      f_name     l_name                           email  branch
# 0  SHASHANK  Chaudhary  shashank.k.chaudhary@gmail.com    SITE
# 1      DIVY  Badgurjar                  divy@gmail.com  SELECT
# 2    RAGHAV      Saboo                 saboo@email.com  SELECT
# 3   ABHINAV      Kumar               abhinav@gmail.com    SITE
# 4     GOWRI       Nath                 gowri@gmail.com  SELECT

# %%
df_new['branch'] = df_new['branch'].replace({'SITE' : 'IT' , 'SELECT' : 'EEE'})
df_new
# Out:
#      f_name     l_name                           email branch
# 0  SHASHANK  Chaudhary  shashank.k.chaudhary@gmail.com     IT
# 1      DIVY  Badgurjar                  divy@gmail.com    EEE
# 2    RAGHAV      Saboo                 saboo@email.com    EEE
# 3   ABHINAV      Kumar               abhinav@gmail.com     IT
# 4     GOWRI       Nath                 gowri@gmail.com    EEE

# %%
df_new['full_name'] = df_new['f_name'] + ' ' + df_new['l_name']
df_new
# Out:
#      f_name     l_name                           email branch  \
# 0  SHASHANK  Chaudhary  shashank.k.chaudhary@gmail.com     IT
# 1      DIVY  Badgurjar                  divy@gmail.com    EEE
# 2    RAGHAV      Saboo                 saboo@email.com    EEE
# 3   ABHINAV      Kumar               abhinav@gmail.com     IT
# 4     GOWRI       Nath                 gowri@gmail.com    EEE
#
#             full_name
# 0  SHASHANK Chaudhary
# 1      DIVY Badgurjar
# 2        RAGHAV Saboo
# 3       ABHINAV Kumar
# 4          GOWRI Nath

# %%
df_new.drop(columns = ['f_name', 'l_name'] , inplace = True)
df_new
# Out:
#                             email branch           full_name
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary
# 1                  divy@gmail.com    EEE      DIVY Badgurjar
# 2                 saboo@email.com    EEE        RAGHAV Saboo
# 3               abhinav@gmail.com     IT       ABHINAV Kumar
# 4                 gowri@gmail.com    EEE          GOWRI Nath

# %%
df_new['full_name'].str.split(' ' , expand = True)
# Out:
#           0          1
# 0  SHASHANK  Chaudhary
# 1      DIVY  Badgurjar
# 2    RAGHAV      Saboo
# 3   ABHINAV      Kumar
# 4     GOWRI       Nath

# %%
df_new[['f_name', 'l_name']] = df_new['full_name'].str.split(' ' , expand = True)
df_new
# Out:
#                             email branch           full_name    f_name  \
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
#
#       l_name
# 0  Chaudhary
# 1  Badgurjar
# 2      Saboo
# 3      Kumar
# 4       Nath

# %%
df_new.append({'f_name' : 'Starc' , 'l_name' : 'Doe'} , ignore_index = True)
# Out:
#                             email branch           full_name    f_name  \
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 5                             NaN    NaN                 NaN     Starc
#
#       l_name
# 0  Chaudhary
# 1  Badgurjar
# 2      Saboo
# 3      Kumar
# 4       Nath
# 5        Doe

# %%
df_append = pd.DataFrame( {'f_name' : ['Yama' , 'Dakuta'] , 'l_name' : ['Gucci' , 'Qamachi']})
df_append
# Out:
#    f_name   l_name
# 0    Yama    Gucci
# 1  Dakuta  Qamachi

# %%
df_new = df_new.append(df_append , ignore_index = True , sort = False)

# %%
df_new
# Out:
#                             email branch           full_name    f_name  \
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 5                             NaN    NaN                 NaN      Yama
# 6                             NaN    NaN                 NaN    Dakuta
#
#       l_name
# 0  Chaudhary
# 1  Badgurjar
# 2      Saboo
# 3      Kumar
# 4       Nath
# 5      Gucci
# 6    Qamachi

# %%
df_new.drop(index= 6)
# Out:
#                             email branch           full_name    f_name  \
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 5                             NaN    NaN                 NaN      Yama
#
#       l_name
# 0  Chaudhary
# 1  Badgurjar
# 2      Saboo
# 3      Kumar
# 4       Nath
# 5      Gucci

# %%
## droping all the rows with branch 'IT'
df_new.drop(index = df_new[df_new['branch'] == 'IT'].index)
# Out:
#              email branch       full_name  f_name     l_name
# 1   divy@gmail.com    EEE  DIVY Badgurjar    DIVY  Badgurjar
# 2  saboo@email.com    EEE    RAGHAV Saboo  RAGHAV      Saboo
# 4  gowri@gmail.com    EEE      GOWRI Nath   GOWRI       Nath
# 5              NaN    NaN             NaN    Yama      Gucci
# 6              NaN    NaN             NaN  Dakuta    Qamachi

# %%
## Same thing as above
filt = (df_new['branch'] == 'IT')
df_new.drop(index = df_new[filt].index)
# Out:
#              email branch       full_name  f_name     l_name
# 1   divy@gmail.com    EEE  DIVY Badgurjar    DIVY  Badgurjar
# 2  saboo@email.com    EEE    RAGHAV Saboo  RAGHAV      Saboo
# 4  gowri@gmail.com    EEE      GOWRI Nath   GOWRI       Nath
# 5              NaN    NaN             NaN    Yama      Gucci
# 6              NaN    NaN             NaN  Dakuta    Qamachi

# %% [markdown]
# ## Sorting Data

# %%
df_new.sort_values(by = 'l_name' , ascending = False) ## Sorting the data by th l_name column in descending order
# Out:
#                             email branch           full_name    f_name  \
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 6                             NaN    NaN                 NaN    Dakuta
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 5                             NaN    NaN                 NaN      Yama
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
#
#       l_name
# 2      Saboo
# 6    Qamachi
# 4       Nath
# 3      Kumar
# 5      Gucci
# 0  Chaudhary
# 1  Badgurjar

# %%
print(df_new.sort_values(by = ['branch' , 'f_name'] , ascending = [False , True]).sort_index())

## This is the difference between reset_index and sort_index

df_new.sort_values(by = ['branch' , 'f_name'] , ascending = [False , True]).reset_index()
### This again sorts the data first on f_name and if common datas in f_name then on l_name
## Ascending has list of bools which is saying sort the data using branch in descending order and f_name in ascending order
# Out:
#                             email branch           full_name    f_name  \
# 0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 5                             NaN    NaN                 NaN      Yama
# 6                             NaN    NaN                 NaN    Dakuta
#
#       l_name
# 0  Chaudhary
# 1  Badgurjar
# 2      Saboo
# 3      Kumar
# 4       Nath
# 5      Gucci
# 6    Qamachi
#    index                           email branch           full_name    f_name  \
# 0      3               abhinav@gmail.com     IT       ABHINAV Kumar   ABHINAV
# 1      0  shashank.k.chaudhary@gmail.com     IT  SHASHANK Chaudhary  SHASHANK
# 2      1                  divy@gmail.com    EEE      DIVY Badgurjar      DIVY
# 3      4                 gowri@gmail.com    EEE          GOWRI Nath     GOWRI
# 4      2                 saboo@email.com    EEE        RAGHAV Saboo    RAGHAV
# 5      6                             NaN    NaN                 NaN    Dakuta
# 6      5                             NaN    NaN                 NaN      Yama
#
#       l_name
# 0      Kumar
# 1  Chaudhary
# 2  Badgurjar
# 3       Nath
# 4      Saboo
# 5    Qamachi
# 6      Gucci

# %%
df_new['f_name'].sort_values()
# Out:
# 3     ABHINAV
# 1        DIVY
# 6      Dakuta
# 4       GOWRI
# 2      RAGHAV
# 0    SHASHANK
# 5        Yama
# Name: f_name, dtype: object

# %%
df.sort_values(by = 'Country')['Country'].head(50)
# Out:
# 8599     Afghanistan
# 24908    Afghanistan
# 57044    Afghanistan
# 41950    Afghanistan
# 50469    Afghanistan
# 37601    Afghanistan
# 28270    Afghanistan
# 7586     Afghanistan
# 43157    Afghanistan
# 61453    Afghanistan
# 50492    Afghanistan
# 36354    Afghanistan
# 43140    Afghanistan
# 63925    Afghanistan
# 38261    Afghanistan
# 35602    Afghanistan
# 43010    Afghanistan
# 36887    Afghanistan
# 43708    Afghanistan
# 35541    Afghanistan
# 64306    Afghanistan
# 43709    Afghanistan
# 23708    Afghanistan
# 41506    Afghanistan
# 63993    Afghanistan
# 43843    Afghanistan
# 59329    Afghanistan
# 895      Afghanistan
# 50847    Afghanistan
# 35052    Afghanistan
# 2918     Afghanistan
# 53923    Afghanistan
# 15371    Afghanistan
# 45879    Afghanistan
# 44571    Afghanistan
# 50812    Afghanistan
# 62520    Afghanistan
# 35511    Afghanistan
# 33755    Afghanistan
# 26477    Afghanistan
# 37284    Afghanistan
# 9806     Afghanistan
# 56146    Afghanistan
# 29781    Afghanistan
# 44504    Afghanistan
# 50641    Afghanistan
# 30491    Afghanistan
# 26676    Afghanistan
# 38761    Afghanistan
# 30451    Afghanistan
# Name: Country, dtype: object

# %%
## Counting unique values in a series
df['Country'].value_counts().head(50)
# Out:
# United States         12469
# India                  8403
# United Kingdom         3896
# Germany                3890
# Canada                 2191
# France                 1898
# Brazil                 1818
# Netherlands            1343
# Poland                 1278
# Australia              1208
# Spain                  1161
# Italy                  1117
# Russian Federation     1092
# Sweden                  886
# Pakistan                809
# Turkey                  777
# Israel                  653
# Switzerland             629
# Bangladesh              609
# Romania                 604
# Nigeria                 593
# Mexico                  540
# Austria                 539
# Ukraine                 539
# Czech Republic          500
# Indonesia               499
# South Africa            494
# Iran                    491
# Belgium                 459
# Ireland                 444
# Philippines             405
# Denmark                 397
# Argentina               395
# Greece                  390
# Portugal                388
# Norway                  384
# Hungary                 371
# China                   371
# Viet Nam                364
# New Zealand             353
# Finland                 349
# Bulgaria                323
# Serbia                  306
# Japan                   297
# Sri Lanka               295
# Colombia                285
# Egypt                   281
# Kenya                   271
# Nepal                   242
# Malaysia                231
# Name: Country, dtype: int64

# %%
## giving the 10 largest values inside the series 'COnvertedComp'
print(df['ConvertedComp'].nlargest(10))

df['ConvertedComp'].nsmallest(10)
# Out:
# 121     2000000.0
# 123     2000000.0
# 191     2000000.0
# 663     2000000.0
# 697     2000000.0
# 722     2000000.0
# 816     2000000.0
# 982     2000000.0
# 1018    2000000.0
# 1032    2000000.0
# Name: ConvertedComp, dtype: float64
# 122     0.0
# 236     0.0
# 882     0.0
# 1112    0.0
# 1272    0.0
# 1785    0.0
# 2064    0.0
# 2187    0.0
# 2239    0.0
# 2314    0.0
# Name: ConvertedComp, dtype: float64

# %%
## returns DataFrame with the highest values of 'ConvertedComp' and similarly works with the nsmallest()
df.nlargest(10 , 'ConvertedComp')
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 121          123                     I am a developer by profession      Yes
# 123          125  I am not primarily a developer, but I write co...      Yes
# 191          193                     I am a developer by profession      Yes
# 663          665                     I am a developer by profession      Yes
# 697          699  I am not primarily a developer, but I write co...      Yes
# 722          724  I am not primarily a developer, but I write co...      Yes
# 816          818  I am not primarily a developer, but I write co...      Yes
# 982          986                     I am a developer by profession      Yes
# 1018        1022                     I am a developer by profession      Yes
# 1032        1036                     I am a developer by profession      Yes
#
#        Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 121   26.0         12   Weekly   120000.0      2000000.0  United States
# 123   41.0         30  Monthly   200000.0      2000000.0  United States
# 191   29.0         16   Weekly   120000.0      2000000.0  United States
# 663   24.0         13   Weekly   150000.0      2000000.0  United States
# 697   39.0         16   Weekly    52000.0      2000000.0  United States
# 722    NaN         12   Weekly   103000.0      2000000.0  United States
# 816   40.0         15   Weekly    70000.0      2000000.0  United States
# 982   27.0         11   Weekly    81000.0      2000000.0  United States
# 1018  34.0         16   Weekly   142000.0      2000000.0  United States
# 1032  26.0         11   Weekly    68500.0      2000000.0  United States
#
#               CurrencyDesc CurrencySymbol  \
# 121   United States dollar            USD
# 123   United States dollar            USD
# 191   United States dollar            USD
# 663   United States dollar            USD
# 697   United States dollar            USD
# 722   United States dollar            USD
# 816   United States dollar            USD
# 982   United States dollar            USD
# 1018  United States dollar            USD
# 1032  United States dollar            USD
#
#                              DatabaseDesireNextYear  \
# 121     Cassandra;Firebase;MongoDB;PostgreSQL;Redis
# 123                                      PostgreSQL
# 191                                             NaN
# 663                                             NaN
# 697   MariaDB;Microsoft SQL Server;MySQL;PostgreSQL
# 722                                             NaN
# 816                         PostgreSQL;Redis;SQLite
# 982                        MongoDB;MySQL;PostgreSQL
# 1018         Elasticsearch;MongoDB;PostgreSQL;Redis
# 1032                             MongoDB;PostgreSQL
#
#                                      DatabaseWorkedWith  \
# 121                                           Cassandra
# 123                                          PostgreSQL
# 191                                                 NaN
# 663                                          PostgreSQL
# 697                          Microsoft SQL Server;MySQL
# 722                                             MongoDB
# 816                     IBM DB2;MySQL;PostgreSQL;SQLite
# 982                            MongoDB;MySQL;PostgreSQL
# 1018                                 MongoDB;PostgreSQL
# 1032  MariaDB;Microsoft SQL Server;MongoDB;MySQL;Pos...
#
#                                                 DevType  \
# 121           Developer, back-end;Developer, full-stack
# 123   Data scientist or machine learning specialist;...
# 191                                   Developer, mobile
# 663                                Developer, front-end
# 697                                System administrator
# 722   Developer, back-end;Engineer, data;System admi...
# 816                            Data or business analyst
# 982   Database administrator;Designer;Developer, bac...
# 1018                              Developer, full-stack
# 1032  Database administrator;Developer, back-end;Dev...
#
#                                                 EdLevel  \
# 121        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 123          Other doctoral degree (Ph.D., Ed.D., etc.)
# 191     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 663        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 697        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 722   Some college/university study without earning ...
# 816        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 982        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1018    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1032                Associate degree (A.A., A.S., etc.)
#
#                                              Employment  \
# 121                                  Employed full-time
# 123                                  Employed full-time
# 191                                  Employed full-time
# 663                                  Employed full-time
# 697   Independent contractor, freelancer, or self-em...
# 722                                  Employed full-time
# 816                                  Employed full-time
# 982                                  Employed full-time
# 1018                                 Employed full-time
# 1032                                 Employed full-time
#
#                                               Ethnicity Gender  \
# 121                        White or of European descent    Man
# 123                        White or of European descent    Man
# 191                        White or of European descent    Man
# 663                Black or of African descent;Biracial  Woman
# 697                        White or of European descent    Man
# 722                         Black or of African descent    Man
# 816                        White or of European descent    Man
# 982                        White or of European descent    Man
# 1018                       White or of European descent    Man
# 1032  White or of European descent;Indigenous (such ...    Man
#
#                                              JobFactors  \
# 121   Languages, frameworks, and other technologies ...
# 123   Flex time or a flexible schedule;Family friend...
# 191   Specific department or team I’d be working on;...
# 663   Diversity of the company or organization;Flex ...
# 697   Diversity of the company or organization;Offic...
# 722   Flex time or a flexible schedule;Remote work o...
# 816   Languages, frameworks, and other technologies ...
# 982   Flex time or a flexible schedule;Languages, fr...
# 1018  Languages, frameworks, and other technologies ...
# 1032  Remote work options;Office environment or comp...
#
#                                   JobSat  \
# 121   Neither satisfied nor dissatisfied
# 123                       Very satisfied
# 191                       Very satisfied
# 663                       Very satisfied
# 697                   Slightly satisfied
# 722                    Very dissatisfied
# 816                    Very dissatisfied
# 982                       Very satisfied
# 1018                      Very satisfied
# 1032                  Slightly satisfied
#
#                                                 JobSeek  \
# 121   I’m not actively looking, but I am open to new...
# 123        I am not interested in new job opportunities
# 191   I’m not actively looking, but I am open to new...
# 663        I am not interested in new job opportunities
# 697                     I am actively looking for a job
# 722   I’m not actively looking, but I am open to new...
# 816                     I am actively looking for a job
# 982   I’m not actively looking, but I am open to new...
# 1018       I am not interested in new job opportunities
# 1032       I am not interested in new job opportunities
#
#                                  LanguageDesireNextYear  \
# 121                                C;C++;Go;Kotlin;Rust
# 123                                              Python
# 191                                   Objective-C;Swift
# 663                      HTML/CSS;JavaScript;TypeScript
# 697   Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 722                                                 NaN
# 816   Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 982              C++;HTML/CSS;JavaScript;PHP;TypeScript
# 1018           HTML/CSS;JavaScript;Scala;SQL;TypeScript
# 1032                      C#;JavaScript;Perl;TypeScript
#
#                                      LanguageWorkedWith  \
# 121            Bash/Shell/PowerShell;C++;Go;Java;Python
# 123                                          Python;SQL
# 191                   Java;JavaScript;Objective-C;Swift
# 663                     HTML/CSS;JavaScript;Python;Ruby
# 697   Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 722                                          JavaScript
# 816   Bash/Shell/PowerShell;HTML/CSS;Java;Python;SQL...
# 982   C;C++;HTML/CSS;Java;JavaScript;Objective-C;PHP...
# 1018      HTML/CSS;Java;JavaScript;Scala;SQL;TypeScript
# 1032  C;C#;HTML/CSS;Java;JavaScript;Perl;PHP;SQL;Typ...
#
#                            MiscTechDesireNextYear  \
# 121       Flutter;Hadoop;TensorFlow;Unreal Engine
# 123         Keras;Pandas;TensorFlow;Torch/PyTorch
# 191                                           NaN
# 663                                       Node.js
# 697    .NET;.NET Core;Pandas;Puppet;Unreal Engine
# 722                                           NaN
# 816   .NET;Ansible;Chef;Node.js;Pandas;TensorFlow
# 982                                       Node.js
# 1018                         Apache Spark;Node.js
# 1032                    .NET Core;Node.js;Xamarin
#
#                                MiscTechWorkedWith  \
# 121                                     .NET Core
# 123                       Keras;Pandas;TensorFlow
# 191                                           NaN
# 663                                       Node.js
# 697                                           NaN
# 722                                       Node.js
# 816                                           NaN
# 982                  Cordova;Node.js;React Native
# 1018                                      Node.js
# 1032  .NET;.NET Core;Node.js;React Native;Xamarin
#
#                            NEWCollabToolsDesireNextYear  \
# 121                        Confluence;Jira;Github;Slack
# 123                                                Jira
# 191   Github;Slack;Trello;Google Suite (Docs, Meet, ...
# 663    Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# 697   Microsoft Teams;Microsoft Azure;Trello;Google ...
# 722                                                 NaN
# 816   Confluence;Jira;Github;Gitlab;Slack;Microsoft ...
# 982              Github;Gitlab;Stack Overflow for Teams
# 1018       Github;Trello;Google Suite (Docs, Meet, etc)
# 1032                    Microsoft Teams;Microsoft Azure
#
#                                NEWCollabToolsWorkedWith NEWDevOps  \
# 121   Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 123                                                Jira  Not sure
# 191   Github;Gitlab;Slack;Microsoft Teams;Trello;Goo...        No
# 663    Jira;Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 697   Jira;Microsoft Teams;Microsoft Azure;Trello;Go...        No
# 722                                               Slack  Not sure
# 816                                   Confluence;Github        No
# 982              Github;Gitlab;Stack Overflow for Teams        No
# 1018  Confluence;Jira;Github;Slack;Trello;Google Sui...       Yes
# 1032  Jira;Github;Microsoft Teams;Microsoft Azure;Go...        No
#
#             NEWDevOpsImpt                           NEWEdImpt  \
# 121    Somewhat important                      Very important
# 123               Neutral                Critically important
# 191               Neutral                    Fairly important
# 663   Extremely important                  Somewhat important
# 697    Somewhat important                Critically important
# 722               Neutral                Critically important
# 816    Somewhat important                    Fairly important
# 982    Somewhat important  Not at all important/not necessary
# 1018  Extremely important                      Very important
# 1032  Extremely important                Critically important
#
#                                              NEWJobHunt  \
# 121   Trouble with my direct manager;Trouble with le...
# 123                            Better work/life balance
# 191   Curious about other opportunities;Better compe...
# 663   Better compensation;Trouble with leadership at...
# 697                  Growth or leadership opportunities
# 722                  Growth or leadership opportunities
# 816   Having a bad day (or week or month) at work;Be...
# 982   Better compensation;Trouble with my direct man...
# 1018  Having a bad day (or week or month) at work;Be...
# 1032  Better compensation;Wanting to work with new t...
#
#                                      NEWJobHuntResearch              NEWLearn  \
# 121   Read company media, such as employee blogs or ...           Once a year
# 123   Personal network - friends or family;Directly ...  Once every few years
# 191   Read company media, such as employee blogs or ...      Every few months
# 663   Read company media, such as employee blogs or ...           Once a year
# 697   Read company media, such as employee blogs or ...           Once a year
# 722   Read other media like news articles, founder p...  Once every few years
# 816   Read company media, such as employee blogs or ...           Once a year
# 982   Read company media, such as employee blogs or ...           Once a year
# 1018  Company reviews from third party sites (e.g. G...  Once every few years
# 1032  Read company media, such as employee blogs or ...           Once a year
#
#      NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 121          Yes                            No            No
# 123           No                           Yes            No
# 191           No  Onboarding? What onboarding?            No
# 663     Not sure                           Yes           Yes
# 697          NaN                            No            No
# 722           No                            No            No
# 816           No                            No            No
# 982           No                           Yes           Yes
# 1018    Not sure                            No            No
# 1032    Not sure                           Yes            No
#
#                                             NEWOvertime  \
# 121                   Rarely: 1-2 days per year or less
# 123   Occasionally: 1-2 days per quarter but less th...
# 191                                               Never
# 663   Occasionally: 1-2 days per quarter but less th...
# 697                    Often: 1-2 days per week or more
# 722                    Often: 1-2 days per week or more
# 816   Occasionally: 1-2 days per quarter but less th...
# 982                   Rarely: 1-2 days per year or less
# 1018                  Rarely: 1-2 days per year or less
# 1032  Occasionally: 1-2 days per quarter but less th...
#
#                                     NEWPurchaseResearch      NEWPurpleLink  \
# 121   Start a free trial;Ask developers I know/work ...        Indifferent
# 123                                                 NaN             Amused
# 191                                                 NaN  Hello, old friend
# 663                                                 NaN        Indifferent
# 697   Start a free trial;Visit developer communities...  Hello, old friend
# 722                                                 NaN        Indifferent
# 816   Ask developers I know/work with;Visit develope...        Indifferent
# 982   Ask developers I know/work with;Visit develope...  Hello, old friend
# 1018                                                NaN            Annoyed
# 1032                                                NaN  Hello, old friend
#
#                                              NEWSOSites  \
# 121   Stack Overflow (public Q&A for anyone who code...
# 123   Stack Overflow (public Q&A for anyone who code...
# 191   Stack Overflow (public Q&A for anyone who code...
# 663   Stack Overflow (public Q&A for anyone who code...
# 697             I have never visited any of these sites
# 722   Stack Overflow (public Q&A for anyone who code...
# 816   Stack Overflow (public Q&A for anyone who code...
# 982   Stack Overflow (public Q&A for anyone who code...
# 1018  Stack Overflow (public Q&A for anyone who code...
# 1032  Stack Overflow (public Q&A for anyone who code...
#
#                                                NEWStuck        OpSys  \
# 121   Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 123   Visit Stack Overflow;Go for a walk or other ph...      Windows
# 191   Play games;Visit Stack Overflow;Do other work ...        MacOS
# 663   Call a coworker or friend;Visit Stack Overflow...        MacOS
# 697   Call a coworker or friend;Visit Stack Overflow...      Windows
# 722   Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 816   Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 982   Call a coworker or friend;Visit Stack Overflow...      Windows
# 1018  Call a coworker or friend;Visit Stack Overflow...        MacOS
# 1032  Visit Stack Overflow;Go for a walk or other ph...      Windows
#
#                        OrgSize  \
# 121   10,000 or more employees
# 123   5,000 to 9,999 employees
# 191         10 to 19 employees
# 663   1,000 to 4,999 employees
# 697       100 to 499 employees
# 722       100 to 499 employees
# 816       100 to 499 employees
# 982   1,000 to 4,999 employees
# 1018      100 to 499 employees
# 1032        20 to 99 employees
#
#                                  PlatformDesireNextYear  \
# 121   Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 123                                   Docker;Kubernetes
# 191                                         Android;iOS
# 663   AWS;Google Cloud Platform;Kubernetes;Linux;Mac...
# 697   Android;Arduino;AWS;Google Cloud Platform;Kube...
# 722                                                 NaN
# 816   Android;AWS;Docker;Google Cloud Platform;Linux...
# 982   Android;Arduino;AWS;Docker;Linux;Raspberry Pi;...
# 1018                              AWS;Docker;Kubernetes
# 1032                                              Linux
#
#                                      PlatformWorkedWith  \
# 121                       AWS;Docker;Linux;Raspberry Pi
# 123                                              Docker
# 191                                         Android;iOS
# 663        Google Cloud Platform;Heroku;MacOS;WordPress
# 697                                           WordPress
# 722                        Docker;Google Cloud Platform
# 816                       AWS;Heroku;Linux;Raspberry Pi
# 982   Android;Arduino;AWS;iOS;Linux;MacOS;Raspberry ...
# 1018                                  AWS;Docker;Heroku
# 1032        Docker;Linux;Raspberry Pi;Windows;WordPress
#
#                        PurchaseWhat                Sexuality  \
# 121           I have some influence  Straight / Heterosexual
# 123   I have little or no influence  Straight / Heterosexual
# 191   I have little or no influence  Straight / Heterosexual
# 663   I have little or no influence           Bisexual;Queer
# 697                             NaN  Straight / Heterosexual
# 722   I have little or no influence  Straight / Heterosexual
# 816           I have some influence  Straight / Heterosexual
# 982           I have some influence  Straight / Heterosexual
# 1018  I have little or no influence  Straight / Heterosexual
# 1032  I have little or no influence  Straight / Heterosexual
#
#                     SOAccount           SOComm  \
# 121                       Yes    Yes, somewhat
# 123   Not sure/can't remember   No, not really
# 191                       Yes   No, not really
# 663                       Yes   No, not really
# 697                       NaN              NaN
# 722                       Yes   No, not at all
# 816                       Yes    Yes, somewhat
# 982                       Yes  Yes, definitely
# 1018                      Yes    Yes, somewhat
# 1032                      Yes    Yes, somewhat
#
#                                              SOPartFreq  \
# 121                 Less than once per month or monthly
# 123                                                 NaN
# 191                 Less than once per month or monthly
# 663   I have never participated in Q&A on Stack Over...
# 697                                                 NaN
# 722   I have never participated in Q&A on Stack Over...
# 816                                A few times per week
# 982                     A few times per month or weekly
# 1018                    A few times per month or weekly
# 1032                    A few times per month or weekly
#
#                           SOVisitFreq                  SurveyEase  \
# 121             Daily or almost daily                        Easy
# 123            Multiple times per day                        Easy
# 191              A few times per week  Neither easy nor difficult
# 663   A few times per month or weekly  Neither easy nor difficult
# 697                               NaN  Neither easy nor difficult
# 722   A few times per month or weekly  Neither easy nor difficult
# 816            Multiple times per day                        Easy
# 982            Multiple times per day                        Easy
# 1018            Daily or almost daily                        Easy
# 1032             A few times per week                        Easy
#
#                SurveyLength Trans  \
# 121   Appropriate in length    No
# 123   Appropriate in length    No
# 191   Appropriate in length    No
# 663   Appropriate in length    No
# 697   Appropriate in length    No
# 722   Appropriate in length    No
# 816   Appropriate in length    No
# 982                Too long    No
# 1018               Too long    No
# 1032  Appropriate in length    No
#
#                                          UndergradMajor  \
# 121   Computer science, computer engineering, or sof...
# 123                                                 NaN
# 191   Computer science, computer engineering, or sof...
# 663   A humanities discipline (such as literature, h...
# 697   Information systems, information technology, o...
# 722   Computer science, computer engineering, or sof...
# 816   A social science (such as anthropology, psycho...
# 982   Computer science, computer engineering, or sof...
# 1018  Computer science, computer engineering, or sof...
# 1032  Computer science, computer engineering, or sof...
#
#                           WebframeDesireNextYear  \
# 121                        Flask;jQuery;React.js
# 123                                          NaN
# 191                                          NaN
# 663                                     React.js
# 697   Angular;ASP.NET;ASP.NET Core;Express;Flask
# 722                                          NaN
# 816                         Angular;Flask;Spring
# 982                              Express;Laravel
# 1018                                    React.js
# 1032                         ASP.NET Core;Vue.js
#
#                                      WebframeWorkedWith  \
# 121                                              Spring
# 123                                                 NaN
# 191                                                 NaN
# 663                      Express;React.js;Ruby on Rails
# 697                                                 NaN
# 722                                            React.js
# 816                                                 NaN
# 982                              Express;jQuery;Laravel
# 1018                 Angular;Angular.js;React.js;Vue.js
# 1032  Angular;ASP.NET;ASP.NET Core;Django;Express;Fl...
#
#                                           WelcomeChange  WorkWeekHrs  \
# 121             Just as welcome now as I felt last year         36.0
# 123             Just as welcome now as I felt last year         40.0
# 191             Just as welcome now as I felt last year         40.0
# 663             Just as welcome now as I felt last year         40.0
# 697                                                 NaN         40.0
# 722   Not applicable - I did not use Stack Overflow ...         40.0
# 816            Somewhat less welcome now than last year         40.0
# 982             Just as welcome now as I felt last year         40.0
# 1018            Just as welcome now as I felt last year         40.0
# 1032              A lot more welcome now than last year         40.0
#
#      YearsCode      YearsCodePro
# 121          8                 3
# 123         11                11
# 191         13                 7
# 663          4  Less than 1 year
# 697          5                 2
# 722          3                 3
# 816         25                 2
# 982         16                 8
# 1018        18                13
# 1032         5                 3
